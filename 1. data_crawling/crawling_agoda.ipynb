# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep

#Khai báo biến browser
browser = webdriver.Chrome(executable_path="chromedriver.exe")
browser.get("https://www.agoda.com/vi-vn/malibu-hotel/hotel/vung-tau-vn.html?finalPriceView=1&isShowMobileAppPrice=false&cid=1734438&numberOfBedrooms=&familyMode=false&adults=1&children=0&rooms=1&maxRooms=0&checkIn=2021-04-15&isCalendarCallout=false&childAges=&numberOfGuest=0&missingChildAges=false&travellerType=-1&showReviewSubmissionEntry=false&currencyCode=VND&isFreeOccSearch=false&tspTypes=16,8&los=1&searchrequestid=dfd52a73-da3b-4ab0-a064-b57e6bc40a92")
sleep(5)

#Hiện bình luận
#showreview = browser.find_element_by_class_name("ficon-carrouselarrow-right")
#showreview.click()

#Tìm tên, điểm, và đánh giá rồi in ra màn hình
review_list = browser.find_elements_by_xpath("//div[@Class='Review-comment']")
for review in review_list:
    user = review.find_element_by_class_name("Review-comment-reviewer")
    score = review.find_element_by_class_name("Review-comment-leftScore")
    print("< >", user.text,"< >",score.text,"< >","*", end="")
    content = review.find_elements_by_class_name("Review-comment-bodyText")
    num_review = len(content)
    for i in range(num_review):
        review=content[i].text
        print(review,"< >", end="")
    print("*")
       
#Kết thúc, tắt trình duyệt
browser.close()
# Out:
# < > Lan từ Việt Nam < > 9,6 < > *Phòng tiện nghi, trang bị đầy đủ. Điểm tâm sáng hơi chán. < >*
# < > Van từ Việt Nam < > 10,0 < > *Đẹp, chất lượng. Chưa phát hiện khiếm khuyết. < >*
# < > Trân < > 10,0 < > *gia đình mình đặt 2 phòng. KS rất đẹp nhân viên vô cùng thân thiện và dễ thương. vịt trí ks rất thuận lợi gần chợ đêm vũng tàu và kế bên công viên thỏ trắng. Các bé nhà mình rất vui, gđ cực ky hài lòng với chuyến đi này. Hồ bơi thì đẹp nước ko có mùi hoá chất như các hồ bơi khác có điều hơi lạnh. Ăn sáng thì rất tuyệt đa dạng món ăn. Chắc chắn sẽ quay lại với Malibu lần nữa < >*
# < > Truc từ Việt Nam < > 8,0 < > *Ưu: Phòng rộng rãi, nội thất đẹp và sang trọng. Nhân viên nhiệt tình, nhanh chóng dù đông khách. Ăn sáng buffet tuy không đa dạng nhưng ngon. Hồ bơi đẹp (có hồ bơi cho bé o.6m nhưng nhỏ). Tiện nghi đa dạng. Khuyết: Không có bãi biển riêng, phải đi bộ mất 5 phút đến biển. Giá đắt. Không có dịch vụ đưa đón. < >*
# ...
